# %%
print("Entering into AI World")
# Out:
# Entering into AI World

# %%
print("Password is Welcome@123")
# Out:
# Password is Welcome@123

# %%
Print("Hello")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print("Hello")
#
# NameError: name 'Print' is not defined

# %%
print(hi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print(hi)
#
# NameError: name 'hi' is not defined
