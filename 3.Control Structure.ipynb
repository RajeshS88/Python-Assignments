# %%
#if loop

# %%
if():
print()
# Out:
#   Cell In[1], line 2
#     print()
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
Voter=int(input("Enter the Age"))
# Out:
# Enter the Age 18

# %%
if(Voter==18):
    print("The Voter age is eligible for poll")
# Out:
# The Voter is eligible for poll

# %%
Voter=int(input("Enter the Age"))
# Out:
# Enter the Age 34

# %%
#if else

# %%
if(Voter<18):
    print("The Voter age is not eligible for poll")
else:
    print("The Voter age is eligible for poll")
# Out:
# The Voter age is eligible for poll

# %%
Voter=int(input("Enter the Age"))
# Out:
# Enter the Age 17

# %%
if(Voter<18):
    print("The Voter age is not eligible for poll")
else:
    print("The Voter age is eligible for poll")
# Out:
# The Voter age is not eligible for poll

# %%
Age=int(input("Enter the Age"))
# Out:
# Enter the Age 17

# %%
#if elif

# %%
if(Age<18):
    print("Children")
elif(Age<35):
    print("Adult")
elif(Age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Children

# %%
Age=int(input("Enter the Age"))
# Out:
# Enter the Age 31

# %%
if(Age<18):
    print("Children")
elif(Age<35):
    print("Adult")
elif(Age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Adult

# %%
Age=int(input("Enter the Age"))
# Out:
# Enter the Age 54

# %%
if(Age<18):
    print("Children")
elif(Age<35):
    print("Adult")
elif(Age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Citizen

# %%
Age=int(input("Enter the Age"))
# Out:
# Enter the Age 63

# %%
if(Age<18):
    print("Children")
elif(Age<35):
    print("Adult")
elif(Age<59):
    print("Citizen")
else:
    print("Senior Citizen")
# Out:
# Senior Citizen

# %%
#for loop

# %%
for temp in manivariable:
    print(temp)

# %%
lists=[21,16,54,41,67]

# %%
for temp in lists:
    print(temp)
# Out:
# 21
# 16
# 54
# 41
# 67

# %%
for Age in lists:
    if(Age<18):
        print("Children")
    elif(Age<35):
        print("Adult")
    elif(Age<59):
        print("Citizen")
    else:
        print("Senior Citizen")
# Out:
# Adult
# Children
# Citizen
# Citizen
# Senior Citizen

# %%
num=int(input("Enter the number:"))
if((num%2)==0):
    print("The entered number is Even Number")
else:
    print("The entered number is Odd Number")
# Out:
# Enter the number: 3
# The entered number is Odd Number

# %%
num=int(input("Enter the Number:"))
if ((num%2)==1):
        print("The Entered Number is Odd Number")
else:
    print("The Entered Number is Even Number")
# Out:
# Enter the Number: 2
# The Entered Number is Even Number

# %%
range(0,8)
# Out:
# range(0, 8)

# %%
print(range)
# Out:
# <class 'range'>

# %%
print(range(0,8))
# Out:
# range(0, 8)

# %%
for num in range(0,8):
    print(num)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# 7

# %%
for num in range(0,8,2):
    print(num)
# Out:
# 0
# 2
# 4
# 6

# %%
for num in range(1,6,3):
    print(num)
# Out:
# 1
# 4
